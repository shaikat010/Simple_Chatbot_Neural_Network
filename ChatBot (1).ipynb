# %%
#1 Mounting the Google Drive

from google.colab import drive
drive.mount('/content/drive')
data_root='https://drive.google.com/drive/folders/1SBYTVdbQSflFeIOfsr5d6oqeD8gYZyBr?usp=drive_link' #Please upload the files in your drive and change the path to it accordingly.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
# url = '/content/drive/folders/1SBYTVdbQSflFeIOfsr5d6oqeD8gYZyBr?usp=sharing'
# with open(url) as datafile:
#   for line in datafile:
#       data = json.loads(line)
#   retail = pd.DataFrame(data)
#   print(retail)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-b1f8e488840a> in <cell line: 5>()
#       3 drive.mount('/content/drive')
#       4 url = 'https://drive.google.com/drive/folders/1SBYTVdbQSflFeIOfsr5d6oqeD8gYZyBr?usp=sharing'
# ----> 5 with open(url) as datafile:
#       6   for line in datafile:
#       7       data = json.loads(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://drive.google.com/drive/folders/1SBYTVdbQSflFeIOfsr5d6oqeD8gYZyBr?usp=sharing'

# %%
#2 Importing Relevant Libraries

import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#3 Loading the Dataset: intents.json

data_file = open("intents.json").read()
data = json.loads(data_file)

data
# Out:
# {'intents': [{'context': '',
#    'patterns': ['Hello', 'Hi there', 'Good morning', "What's up"],
#    'responses': ['Hey!', 'Hello', 'Hi!', 'Good morning!'],
#    'tag': 'hello'},
#   {'context': [''],
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'tag': 'noanswer'},
#   {'context': '',
#    'patterns': ['What is your job', 'What is your work'],
#    'responses': ['My job is to make you feel like everything is okay.',
#     'I work to serve you as well as possible'],
#    'tag': 'job'},
#   {'context': '',
#    'patterns': ['What is your age', 'How old are you', 'When were you born'],
#    'responses': ['I was born in 2021'],
#    'tag': 'age'},
#   {'context': '',
#    'patterns': ['How are you today', 'How are you'],
#    'responses': ['I am feeling good, you?',
#     'Very good and you?',
#     "Actually, I'm okay and you?"],
#    'tag': 'feeling'},
#   {'context': 'feeling',
#    'patterns': ['I am good too',
#     'I feel fine',
#     'Good !',
#     'Fine',
#     'I am good',
#     'I am great',
#     'great'],
#    'responses': ['That is perfect!', "So, everything's okay!"],
#    'tag': 'good'},
#   {'context': 'feeling',
#    'patterns': ['I am feeling bad', 'No I am sad', 'No'],
#    'responses': ['I hope you will feel better !'],
#    'tag': 'bad'},
#   {'context': '',
#    'patterns': ['What can you do', 'What can I ask you', 'Can you help me'],
#    'responses': ['I can do a lot of things but here are some of my skills, you can ask me: the capital of a country, its currency and its area. A random number. To calculate a math operation.'],
#    'tag': 'actions'},
#   {'context': '',
#    'patterns': ['Are you a girl', 'You are a women'],
#    'responses': ['Sure, I am a women'],
#    'tag': 'women'},
#   {'context': '',
#    'patterns': ['Are you a men', 'Are you a boy'],
#    'responses': ['No, I am a women'],
#    'tag': 'men'},
#   {'context': '',
#    'patterns': ['Thank you', 'Thank you very much', 'thanks'],
#    'responses': ['I only do my job️', 'No problem!'],
#    'tag': 'thanks'},
#   {'context': '',
#    'patterns': ['Goodbye', 'Good afternoon', 'Bye'],
#    'responses': ['Goodbye!', 'See you soon!'],
#    'tag': 'goodbye'},
#   {'context': '',
#    'patterns': ['Where do you live'],
#    'responses': ['I live in a server located in the US!'],
#    'tag': 'city'},
#   {'context': '',
#    'patterns': ['What are you doing'],
#    'responses': ["Actually, I'm chatting with somebody"],
#    'tag': 'action'},
#   {'context': '',
#    'patterns': ['Can you wait 2 minutes', 'Please wait', 'Wait 2 secs please'],
#    'responses': ['Sure! I wait.'],
#    'tag': 'wait'},
#   {'context': '',
#    'patterns': ['Are you still there?', 'Are you here?'],
#    'responses': ['Of course! Always at your service.'],
#    'tag': 'still there'}]}

# %%
#4 Extracting data_X(features) and data_Y(Target)

words = [] #For Bow model/ vocabulary for patterns
classes = [] #For Bow  model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data_X
# Iterating over all the intents

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern) # tokenize each pattern
        words.extend(tokens) #and append tokens to words
        data_X.append(pattern) #appending pattern to data_X
        data_y.append(intent["tag"]) ,# appending the associated tag to each pattern

    # adding the tag to the classes if it's not there already
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# 5 Text to Numbers
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               7552
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 16)                1040
#
# =================================================================
# Total params: 16,848
# Trainable params: 16,848
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 19ms/step - loss: 2.8022 - accuracy: 0.0488
# Epoch 2/150
# 2/2 [==============================] - 0s 9ms/step - loss: 2.6282 - accuracy: 0.1220
# Epoch 3/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.5876 - accuracy: 0.1707
# Epoch 4/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4038 - accuracy: 0.3171
# Epoch 5/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2709 - accuracy: 0.3415
# Epoch 6/150
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0753 - accuracy: 0.4146
# Epoch 7/150
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9846 - accuracy: 0.4146
# Epoch 8/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.7874 - accuracy: 0.4146
# Epoch 9/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5202 - accuracy: 0.6341
# Epoch 10/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.6839 - accuracy: 0.4878
# Epoch 11/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3898 - accuracy: 0.5854
# Epoch 12/150
# 2/2 [==============================] - 0s 12ms/step - loss: 1.1626 - accuracy: 0.6585
# Epoch 13/150
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0106 - accuracy: 0.7317
# Epoch 14/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0774 - accuracy: 0.6098
# Epoch 15/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0283 - accuracy: 0.6829
# Epoch 16/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6612 - accuracy: 0.8780
# Epoch 17/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7130 - accuracy: 0.7561
# Epoch 18/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7620 - accuracy: 0.7073
# Epoch 19/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7990 - accuracy: 0.7073
# Epoch 20/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5452 - accuracy: 0.8049
# Epoch 21/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6979 - accuracy: 0.8293
# Epoch 22/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5431 - accuracy: 0.7561
# Epoch 23/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5436 - accuracy: 0.8293
# Epoch 24/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3618 - accuracy: 0.9024
# Epoch 25/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4213 - accuracy: 0.8537
# Epoch 26/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4120 - accuracy: 0.9024
# Epoch 27/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4412 - accuracy: 0.8537
# Epoch 28/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3191 - accuracy: 0.9512
# Epoch 29/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4817 - accuracy: 0.8049
# Epoch 30/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2688 - accuracy: 0.9024
# Epoch 31/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2726 - accuracy: 0.8780
# Epoch 32/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3072 - accuracy: 0.9024
# Epoch 33/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4206 - accuracy: 0.9024
# Epoch 34/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2556 - accuracy: 0.9268
# Epoch 35/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2428 - accuracy: 0.9024
# Epoch 36/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2363 - accuracy: 0.9512
# Epoch 37/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2790 - accuracy: 0.9268
# Epoch 38/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3355 - accuracy: 0.8780
# Epoch 39/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2885 - accuracy: 0.9024
# Epoch 40/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1798 - accuracy: 0.9268
# Epoch 41/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1566 - accuracy: 0.9756
# Epoch 42/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3194 - accuracy: 0.8780
# Epoch 43/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2094 - accuracy: 0.9268
# Epoch 44/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2838 - accuracy: 0.9024
# Epoch 45/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2415 - accuracy: 0.9268
# Epoch 46/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1832 - accuracy: 0.9512
# Epoch 47/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1447 - accuracy: 0.9512
# Epoch 48/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3145 - accuracy: 0.8780
# Epoch 49/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2291 - accuracy: 0.9024
# Epoch 50/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2076 - accuracy: 0.9512
# Epoch 51/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1554 - accuracy: 0.9756
# Epoch 52/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2119 - accuracy: 0.9268
# Epoch 53/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2248 - accuracy: 0.9024
# Epoch 54/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2848 - accuracy: 0.9268
# Epoch 55/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1850 - accuracy: 0.9512
# Epoch 56/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1908 - accuracy: 0.9268
# Epoch 57/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1825 - accuracy: 0.9024
# Epoch 58/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3245 - accuracy: 0.9024
# Epoch 59/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1399 - accuracy: 0.9512
# Epoch 60/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1195 - accuracy: 1.0000
# Epoch 61/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2305 - accuracy: 0.9024
# Epoch 62/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2620 - accuracy: 0.8780
# Epoch 63/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1345 - accuracy: 0.9756
# Epoch 64/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3259 - accuracy: 0.8780
# Epoch 65/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1562 - accuracy: 0.9268
# Epoch 66/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3537 - accuracy: 0.8780
# Epoch 67/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3158 - accuracy: 0.9024
# Epoch 68/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3142 - accuracy: 0.8537
# Epoch 69/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1765 - accuracy: 0.9512
# Epoch 70/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1898 - accuracy: 0.9268
# Epoch 71/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1551 - accuracy: 0.9512
# Epoch 72/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1348 - accuracy: 0.9512
# Epoch 73/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1385 - accuracy: 0.9512
# Epoch 74/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1109 - accuracy: 0.9756
# Epoch 75/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2374 - accuracy: 0.9268
# Epoch 76/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2829 - accuracy: 0.9268
# Epoch 77/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1535 - accuracy: 0.9512
# Epoch 78/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1084 - accuracy: 0.9756
# Epoch 79/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1339 - accuracy: 0.9268
# Epoch 80/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0766 - accuracy: 1.0000
# Epoch 81/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1327 - accuracy: 0.9512
# Epoch 82/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 83/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1073 - accuracy: 0.9512
# Epoch 84/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1930 - accuracy: 0.9024
# Epoch 85/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1500 - accuracy: 0.9512
# Epoch 86/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0882 - accuracy: 0.9756
# Epoch 87/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1479 - accuracy: 0.9512
# Epoch 88/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0701 - accuracy: 0.9756
# Epoch 89/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 90/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1542 - accuracy: 0.9512
# Epoch 91/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 92/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0570 - accuracy: 0.9756
# Epoch 93/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0952 - accuracy: 0.9756
# Epoch 94/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0775 - accuracy: 0.9756
# Epoch 95/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0744 - accuracy: 1.0000
# Epoch 96/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0859 - accuracy: 1.0000
# Epoch 97/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 98/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1242 - accuracy: 0.9512
# Epoch 99/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0675 - accuracy: 0.9512
# Epoch 100/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1217 - accuracy: 0.9512
# Epoch 101/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1074 - accuracy: 0.9512
# Epoch 102/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0834 - accuracy: 0.9756
# Epoch 103/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0916 - accuracy: 0.9756
# Epoch 104/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1084 - accuracy: 0.9756
# Epoch 105/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0969 - accuracy: 0.9512
# Epoch 106/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.9024
# Epoch 107/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1412 - accuracy: 0.9268
# Epoch 108/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1480 - accuracy: 0.9024
# Epoch 109/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0548 - accuracy: 0.9512
# Epoch 110/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0881 - accuracy: 0.9756
# Epoch 111/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1292 - accuracy: 0.9268
# Epoch 112/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1052 - accuracy: 0.9512
# Epoch 113/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0774 - accuracy: 0.9756
# Epoch 114/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2162 - accuracy: 0.9024
# Epoch 115/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1609 - accuracy: 0.9024
# Epoch 116/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1337 - accuracy: 0.9756
# Epoch 117/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0988 - accuracy: 0.9512
# Epoch 118/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0778 - accuracy: 1.0000
# Epoch 119/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0596 - accuracy: 0.9756
# Epoch 120/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0917 - accuracy: 0.9756
# Epoch 121/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1149 - accuracy: 0.9512
# Epoch 122/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0899 - accuracy: 0.9756
# Epoch 123/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0703 - accuracy: 0.9756
# Epoch 124/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.9268
# Epoch 125/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0972 - accuracy: 0.9756
# Epoch 126/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0706 - accuracy: 0.9756
# Epoch 127/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0593 - accuracy: 0.9756
# Epoch 128/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0985 - accuracy: 0.9756
# Epoch 129/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0688 - accuracy: 0.9756
# Epoch 130/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1378 - accuracy: 0.9268
# Epoch 131/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1475 - accuracy: 0.9512
# Epoch 132/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0944 - accuracy: 0.9512
# Epoch 133/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 134/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1809 - accuracy: 0.9024
# Epoch 135/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0726 - accuracy: 0.9512
# Epoch 136/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0872 - accuracy: 0.9268
# Epoch 137/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 138/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1024 - accuracy: 0.9756
# Epoch 139/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1266 - accuracy: 0.9512
# Epoch 140/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0396 - accuracy: 0.9756
# Epoch 141/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0706 - accuracy: 0.9756
# Epoch 142/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1002 - accuracy: 0.9512
# Epoch 143/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0975 - accuracy: 0.9756
# Epoch 144/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0840 - accuracy: 0.9756
# Epoch 145/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1077 - accuracy: 0.9512
# Epoch 146/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0722 - accuracy: 0.9756
# Epoch 147/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2532 - accuracy: 0.9268
# Epoch 148/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1191 - accuracy: 0.9512
# Epoch 149/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2007 - accuracy: 0.9268
# Epoch 150/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0581 - accuracy: 0.9512

# %%
#7 Preprocessing the Input

def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] #Extracting probabilities
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) #Sorting by values of probability in decreasing order
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]]) #Contains labels(tags) for highest probability
  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
# Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
      break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# no
# 1/1 [==============================] - 0s 91ms/step
# I hope you will feel better !
# hi!
# 1/1 [==============================] - 0s 21ms/step
# Hello
# what is your name!
# 1/1 [==============================] - 0s 32ms/step
# I was born in 2021
# 0
